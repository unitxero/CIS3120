# %% [markdown]
# ### CIS3120 Homework 4
# - Due by 05/19
# - Submit through the blackboard link.
# - Submit the notebook file (.ipynb) as required.

# %% [markdown]
# 1. Draw appropriate line charts of the financial data of ABC Inc. between 10/03/2016 to 10/07/2016. (10 points)
# - Set the line plot for "low price" as black.
# - Rename x label as "Date" and rename y label as "Stock Price".
# - Set best legend location.
#
# date = ['10-03-16','10-04-16','10-05-16','10-06-16','10-07-16']<br>
# open = [774.25, 776.030029, 779.309, 779.780,779.658]<br>
# high = [776.065, 778.710022, 782.07007, 775.539978, 779.659973]<br>
# low = [769.5,772.890015,775.650024, 775.539978, 770.75 ]<br>
# close = [772.559998, 776.429993, 776.469971, 776.859985, 775.080017 ]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
date = ['10-03-16','10-04-16','10-05-16','10-06-16','10-07-16']
open = [774.25, 776.030029, 779.309, 779.780,779.658]
high = [776.065, 778.710022, 782.07007, 775.539978, 779.659973]
low = [769.5,772.890015,775.650024, 775.539978, 770.75]
close = [772.559998, 776.429993, 776.469971, 776.859985, 775.080017]

# %%
# setting figure size
fig = plt.figure(figsize=(12,6))

# plotting lines and assigning labels for the legend
plt.plot(date, high, label = 'high')
plt.plot(date, low, color = 'black', label = 'low')
plt.plot(date, close, label = 'close')
plt.plot(date, open, label = 'open')

# labels
plt.xlabel('Date')
plt.ylabel('Stock Price in $')
plt.title('Financial data of ABC Inc. Between 10/03/2016 to 10/07/2016')

# legend
plt.legend(loc = 'best')

# %% [markdown]
# 2. Create the following bar plot based on the given data (10 points)
#
# x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'] <br>
# popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7] <br>

# %%
x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

# %%
# setting figure size

fig = plt.figure(figsize=(12,6))
plt.ylim(0, 25)

# plotting bar chart

ax = sns.barplot(x = x, y = popularity, color = 'blue')

# labels

plt.ylabel("Popularity", size = 14)
plt.xlabel("Languages", size = 14)
plt.title(label = "Popularity of Programming Languages \n Worldwide, Oct 2017 compared to a year ago", size = 14)

# setting max value for each bar

ax.bar_label(ax.containers[0], size = 16)
# Out:
# [Text(0, 0, '22.2'),
#  Text(0, 0, '17.6'),
#  Text(0, 0, '8.8'),
#  Text(0, 0, '8'),
#  Text(0, 0, '7.7'),
#  Text(0, 0, '6.7')]

# %%
#2

#Expected plot

# %% [markdown]
# 3. Draw the following scatter plot based on the given data (camparing weights and heights in three different groups) (10 points)
#
# weight1=[67,57.2,59.6,59.64,55.8,61.2,60.45,61,56.23,56] <br>
# height1=[101.7,197.6,98.3,125.1,113.7,157.7,136,148.9,125.3,114.9] <br>
# weight2=[61.9,64,62.1,64.2,62.3,65.4,62.4,61.4,62.5,63.6] <br>
# height2=[152.8,155.3,135.1,125.2,151.3,135,182.2,195.9,165.1,125.1] <br>
# weight3=[68.2,67.2,68.4,68.7,71,71.3,70.8,70,71.1,71.7] <br>
# height3=[165.8,170.9,192.8,135.4,161.4,136.1,167.1,235.1,181.1,177.3] <br>

# %%
weight1=[67,57.2,59.6,59.64,55.8,61.2,60.45,61,56.23,56]
height1=[101.7,197.6,98.3,125.1,113.7,157.7,136,148.9,125.3,114.9]
weight2=[61.9,64,62.1,64.2,62.3,65.4,62.4,61.4,62.5,63.6]
height2=[152.8,155.3,135.1,125.2,151.3,135,182.2,195.9,165.1,125.1]
weight3=[68.2,67.2,68.4,68.7,71,71.3,70.8,70,71.1,71.7]
height3=[165.8,170.9,192.8,135.4,161.4,136.1,167.1,235.1,181.1,177.3]

# %%
# plots
plt.scatter(weight1, height1)
plt.scatter(weight2, height2)
plt.scatter(weight3, height3)

# labels

plt.ylabel('Height', size = 13)
plt.xlabel('Weight', size = 13)
plt.title("Group wise Weight vs Height scatter plot", size = 15)
# Out:
# Text(0.5, 1.0, 'Group wise Weight vs Height scatter plot')

# %%
#3

#Expected plot
# Out:
# Text(0.5, 1.0, 'Group wise Weight vs Height scatter plot')

# %% [markdown]
# 4. Complete the following questions based on the "Real estate" dataset.
#
# 4.1 Import the real estate dataset (Real estate.csv) and set the first column as index (5 points)

# %%
path = r'/Users/pegasuspro/Downloads/Real_estate.csv'

df = pd.read_csv(path, index_col= 'No')
df
# Out:
#      transaction date  house age  distance to the nearest MRT station  \
# No
# 1            2012.917       32.0                             84.87882
# 2            2012.917       19.5                            306.59470
# 3            2013.583       13.3                            561.98450
# 4            2013.500       13.3                            561.98450
# 5            2012.833        5.0                            390.56840
# ..                ...        ...                                  ...
# 410          2013.000       13.7                           4082.01500
# 411          2012.667        5.6                             90.45606
# 412          2013.250       18.8                            390.96960
# 413          2013.000        8.1                            104.81010
# 414          2013.500        6.5                             90.45606
#
#      number of convenience stores  latitude  longitude  \
# No
# 1                              10  24.98298  121.54024
# ...

# %% [markdown]
# 4.2
# - Find basic statistical details like percentile, mean, std etc. of real estate data. (5 points)
# - Build a correlation table for all variables in this dataset. What have you found from this table? (10 points)

# %%
#4.2
df.describe()
# Out:
#        transaction date   house age  distance to the nearest MRT station  \
# count        414.000000  414.000000                           414.000000
# mean        2013.148971   17.712560                          1083.885689
# std            0.281967   11.392485                          1262.109595
# min         2012.667000    0.000000                            23.382840
# 25%         2012.917000    9.025000                           289.324800
# 50%         2013.167000   16.100000                           492.231300
# 75%         2013.417000   28.150000                          1454.279000
# max         2013.583000   43.800000                          6488.021000
#
#        number of convenience stores    latitude   longitude  \
# count                    414.000000  414.000000  414.000000
# mean                       4.094203   24.969030  121.533361
# std                        2.945562    0.012410    0.015347
# min                        0.000000   24.932070  121.473530
# ...

# %%
# Out:
# '\nThere is a positive correlation with house price of unit area & number of convenience stores\nThere is a negative correlation with number of convenience stores & distance to nearest MRT station\nThere is a negative correlation with house price of unit area & distance to nearest MRT station\n\n'

# %%
corr_data = df.corr()
sns.heatmap(data = corr_data, annot=True, linewidths = 2, cmap = 'Greens')

'''

There is a positive correlation with house price of unit area & number of convenience stores
There is a negative correlation with number of convenience stores & distance to nearest MRT station
There is a negative correlation with house price of unit area & distance to nearest MRT station

'''
# Out:
# '\n\nThere is a positive correlation with house price of unit area & number of convenience stores\nThere is a negative correlation with number of convenience stores & distance to nearest MRT station\nThere is a negative correlation with house price of unit area & distance to nearest MRT station\n\n'

# %% [markdown]
# 4.3 Build a linear regression model to predict house price of unit area. Explain your results. (20 points)

# %%
# getting the independent variables i want to use
X_features = df.drop(['transaction date','latitude','longitude','house price of unit area'], axis= 1)

# setting my dependent variable
Y_target = df['house price of unit area']

# %%
from sklearn.linear_model import LinearRegression

lineReg = LinearRegression(fit_intercept = True)

# %%
lineReg.fit(X_features, Y_target)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X_features,Y_target)

# %%
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)

# X_train has 310 rows and 3 columns
# X_test has 104 rows and 3 columns
# Y_train has 310 rows
# Y_test has 104 rows
# Out:
# (310, 3) (104, 3) (310,) (104,)

# %%
# fit the training sets into the model
lineReg.fit(X_train,Y_train)

# using the LinearRegression() function
# we use the training set
# and get a line of best fit
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score

#importing to find mean_squared_error and r squared

# Make predictions using the training set
# predicting our y (dependent variable) based on the given
# independent variables (x_train) data
y_train_predict = lineReg.predict(X_train)

# %%
rmse = np.sqrt(mean_squared_error(Y_train,y_train_predict))

'''
Root Mean Square Error (RMSE) is the
standard deviation of the residuals (prediction errors).
Residuals are a measure of how far
from the regression line data points are;
RMSE is a measure of how spread out these residuals are.

In other words, it tells you
how concentrated the data is around the line of best fit.
We have 9.3206 for RMSE
'''

r2 = r2_score(Y_train, y_train_predict)
print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

'''
R-Squared
0% indicates that the model explains none of the variability of the response data around its mean. 100% indicates that the model explains all the variability of the response data around its mean. In general, the higher the R-squared, the better the model fits your data.
We have 54% here. It is an possibly usable model.
'''
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 9.320617639276493
# R2 score is 0.5412993993995787

# %%
# model evaluation for testing set

y_test_predict = lineReg.predict(X_test)
# root mean square error of the model
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))

# r-squared score of the model
r2 = r2_score(Y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for testing set
# --------------------------------------
# RMSE is 8.957835626727292
# R2 score is 0.5146015249293047

# %%
# plotting the y_test vs y_pred
# ideally should have been a straight line
sns.regplot(Y_test, y_test_predict)
plt.show()

# there are many outliers here, also well past the 95% confidence interval.
# this model may not be great at all in predicting the house price of unit area in the outer bands
# but between 30-40, it may have some usefulness in predicting it.
# Out:
# /Users/pegasuspro/PycharmProjects/CIS3120/venv/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# 5. Implement logistical regression model to the banking dataset and explore the relationship between 'age','education','default' ,'duration','pdays','previous' and 'y'. Explain your results. (30 points)
#
# - Data source: https://raw.githubusercontent.com/madmashup/targeted-marketing-predictive-engine/master/banking.csv
#
#
# Variables:
# 1. age (numeric)
# 2. education (categorical: “basic.4y”, “basic.6y”, “basic.9y”, “high.school”, “illiterate”, “professional.course”, “university.degree”, “unknown”)
# 3. default: has credit in default? (categorical: “no”, “yes”, “unknown”)
# 4. duration: last contact duration, in seconds (numeric).
# 5. pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
# 6. previous: number of contacts performed before this campaign and for this client (numeric)
#
# y: has the client subscribed a term deposit? (binary: “1”, means “Yes”, “0” means “No”)

# %%
#5

df_2 = pd.read_csv("https://raw.githubusercontent.com/madmashup/targeted-marketing-predictive-engine/master/banking.csv")

# %%
df_2
# Out:
#        age          job  marital            education  default housing loan  \
# 0       44  blue-collar  married             basic.4y  unknown     yes   no
# 1       53   technician  married              unknown       no      no   no
# 2       28   management   single    university.degree       no     yes   no
# 3       39     services  married          high.school       no      no   no
# 4       55      retired  married             basic.4y       no     yes   no
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   59      retired  married          high.school  unknown      no  yes
# 41184   31    housemaid  married             basic.4y  unknown      no   no
# 41185   42       admin.   single    university.degree  unknown     yes  yes
# 41186   48   technician  married  professional.course       no      no  yes
# 41187   25      student   single          high.school       no      no   no
#
# ...

# %%
x_features_2 = df_2[['age', 'education', 'default', 'duration', 'pdays', 'previous']]

y_target_2 = df_2['y']

# %%
x_features_2
# Out:
#        age            education  default  duration  pdays  previous
# 0       44             basic.4y  unknown       210    999         0
# 1       53              unknown       no       138    999         0
# 2       28    university.degree       no       339      6         2
# 3       39          high.school       no       185    999         0
# 4       55             basic.4y       no       137      3         1
# ...    ...                  ...      ...       ...    ...       ...
# 41183   59          high.school  unknown       222    999         0
# 41184   31             basic.4y  unknown       196    999         0
# 41185   42    university.degree  unknown        62    999         0
# 41186   48  professional.course       no       200    999         0
# 41187   25          high.school       no       112    999         0
#
# [41188 rows x 6 columns]

# %%
x_features_dummies = pd.get_dummies(x_features_2, columns=['education', 'default'], drop_first= True)
x_features_dummies
# Out:
#        age  duration  pdays  previous  education_basic.6y  education_basic.9y  \
# 0       44       210    999         0                   0                   0
# 1       53       138    999         0                   0                   0
# 2       28       339      6         2                   0                   0
# 3       39       185    999         0                   0                   0
# 4       55       137      3         1                   0                   0
# ...    ...       ...    ...       ...                 ...                 ...
# 41183   59       222    999         0                   0                   0
# 41184   31       196    999         0                   0                   0
# 41185   42        62    999         0                   0                   0
# 41186   48       200    999         0                   0                   0
# 41187   25       112    999         0                   0                   0
#
# ...

# %%
#Logistic Regression

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import statsmodels.api as sm

logit = LogisticRegression(solver = 'liblinear', random_state = 0)
logit.fit(x_features_dummies,y_target_2)


confusion_matrix(y_target_2, logit.predict(x_features_dummies))
'''
Model predicted Negative, and got Negative 35757 times

Model predicted Negative, and got 791 positive

Model predicted Positive, got 3115 Negative

Model predicted Positive, got 1525 negative.

This model is pretty good at predicting when client wont be subscribed to a term deposit
'''
# Out:
# array([[35757,   791],
#        [ 3115,  1525]])

# %%
# implement logit model

x1 = sm.add_constant(x_features_dummies)
model = sm.Logit(y_target_2, x_features_dummies)
result = model.fit(method='bfgs')
print(result.summary())
#result.params
#result.pred_table()
# Out:
# /Users/pegasuspro/PycharmProjects/CIS3120/venv/lib/python3.10/site-packages/statsmodels/discrete/discrete_model.py:1819: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/pegasuspro/PycharmProjects/CIS3120/venv/lib/python3.10/site-packages/statsmodels/discrete/discrete_model.py:1872: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/pegasuspro/PycharmProjects/CIS3120/venv/lib/python3.10/site-packages/statsmodels/discrete/discrete_model.py:1819: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/pegasuspro/PycharmProjects/CIS3120/venv/lib/python3.10/site-packages/statsmodels/discrete/discrete_model.py:1872: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# ...
#          Current function value: 0.255454
#          Iterations: 35
#          Function evaluations: 46
#          Gradient evaluations: 40
# ...

# %%
'''
Looks like Duration, previous, education_illiterate, education_unknown
are things that postively increase the chance of the client being subscribed to a term deposit
'''
